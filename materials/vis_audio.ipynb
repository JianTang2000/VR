# %%
import matplotlib.pyplot as plt
from matplotlib.collections import EventCollection
import numpy as np
import math
import torchaudio

print("OK")
# Out:
# OK

# %%
waveform, sample_rate = torchaudio.load("300.wav")
print(sample_rate)
print(waveform.shape)
print(f"length of audio is {waveform.shape[1] / sample_rate} s")
plt.plot(waveform[:, 0:200].t().numpy())
# Out:
# 22050
# torch.Size([1, 2205])
# length of audio is 0.1 s
